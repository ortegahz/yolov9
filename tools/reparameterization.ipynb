# %%
import torch
from models.yolo import Model

# %% [markdown]
# ## Convert YOLOv9-S

# %%
device = torch.device("cpu")
cfg = "/tmp/pycharm_project_283/models/detect/gelan-s.yaml"
model = Model(cfg, ch=3, nc=3, anchors=3)
#model = model.half()
model = model.to(device)
_ = model.eval()
ckpt = torch.load('/home/Huangzhe/test/runs/train_smoke/yolov9-s-smoke-s640_/weights/best.pt', map_location='cpu')
model.names = ckpt['model'].names
# model.nc = ckpt['model'].nc
model.nc = 3
# Out:
# Overriding model.yaml anchors with anchors=3
#
#                  from  n    params  module                                  arguments
# activation: nn.ReLU()
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     31104  models.common.ELAN1                     [64, 64, 64, 32]
#   3                -1  1     73984  models.common.AConv                     [64, 128]
#   4                -1  1    258432  models.common.RepNCSPELAN4              [128, 128, 128, 64, 3]
#   5                -1  1    221568  models.common.AConv                     [128, 192]
#   6                -1  1    579648  models.common.RepNCSPELAN4              [192, 192, 192, 96, 3]
#   7                -1  1    442880  models.common.AConv                     [192, 256]
#   8                -1  1   1028864  models.common.RepNCSPELAN4              [256, 256, 256, 128, 3]
#   9                -1  1    164608  models.common.SPPELAN                   [256, 256, 128]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1    628800  models.common.RepNCSPELAN4              [448, 192, 192, 96, 3]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    283008  models.common.RepNCSPELAN4              [320, 128, 128, 64, 3]
#  16                -1  1    110784  models.common.AConv                     [128, 96]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1    598080  models.common.RepNCSPELAN4              [288, 192, 192, 96, 3]
#  19                -1  1    221440  models.common.AConv                     [192, 128]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   1061632  models.common.RepNCSPELAN4              [384, 256, 256, 128, 3]
#  22      [15, 18, 21]  1   1472089  models.yolo.DDetect                     [3, [128, 192, 256]]
# gelan-s summary: 920 layers, 7196409 parameters, 7196393 gradients, 26.9 GFLOPs
#
# /tmp/ipykernel_1339408/2389840895.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load('/home/Huangzhe/test/runs/train_smoke/yolov9-s-smoke-s640_/weights/best.pt', map_location='cpu')

# %%
idx = 0
for k, v in model.state_dict().items():
    if "model.{}.".format(idx) in k:
        if idx < 22:
            kr = k.replace("model.{}.".format(idx), "model.{}.".format(idx))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv2.".format(idx) in k:
            kr = k.replace("model.{}.cv2.".format(idx), "model.{}.cv4.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv3.".format(idx) in k:
            kr = k.replace("model.{}.cv3.".format(idx), "model.{}.cv5.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.dfl.".format(idx) in k:
            kr = k.replace("model.{}.dfl.".format(idx), "model.{}.dfl2.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
    else:
        while True:
            idx += 1
            if "model.{}.".format(idx) in k:
                break
        if idx < 22:
            kr = k.replace("model.{}.".format(idx), "model.{}.".format(idx))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv2.".format(idx) in k:
            kr = k.replace("model.{}.cv2.".format(idx), "model.{}.cv4.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv3.".format(idx) in k:
            kr = k.replace("model.{}.cv3.".format(idx), "model.{}.cv5.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.dfl.".format(idx) in k:
            kr = k.replace("model.{}.dfl.".format(idx), "model.{}.dfl2.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
_ = model.eval()
# Out:
# model.0.conv.weight
# model.0.conv.weight perfectly matched!!
# model.0.bn.weight
# model.0.bn.weight perfectly matched!!
# model.0.bn.bias
# model.0.bn.bias perfectly matched!!
# model.0.bn.running_mean
# model.0.bn.running_mean perfectly matched!!
# model.0.bn.running_var
# model.0.bn.running_var perfectly matched!!
# model.0.bn.num_batches_tracked
# model.0.bn.num_batches_tracked perfectly matched!!
# model.1.conv.weight
# model.1.conv.weight perfectly matched!!
# model.1.bn.weight
# model.1.bn.weight perfectly matched!!
# model.1.bn.bias
# model.1.bn.bias perfectly matched!!
# model.1.bn.running_mean
# model.1.bn.running_mean perfectly matched!!
# model.1.bn.running_var
# model.1.bn.running_var perfectly matched!!
# model.1.bn.num_batches_tracked
# model.1.bn.num_batches_tracked perfectly matched!!
# model.2.cv1.conv.weight
# model.2.cv1.conv.weight perfectly matched!!
# model.2.cv1.bn.weight
# model.2.cv1.bn.weight perfectly matched!!
# model.2.cv1.bn.bias
# model.2.cv1.bn.bias perfectly matched!!
# model.2.cv1.bn.running_mean
# model.2.cv1.bn.running_mean perfectly matched!!
# model.2.cv1.bn.running_var
# model.2.cv1.bn.running_var perfectly matched!!
# model.2.cv1.bn.num_batches_tracked
# model.2.cv1.bn.num_batches_tracked perfectly matched!!
# model.2.cv2.conv.weight
# model.2.cv2.conv.weight perfectly matched!!
# model.2.cv2.bn.weight
# model.2.cv2.bn.weight perfectly matched!!
# model.2.cv2.bn.bias
# model.2.cv2.bn.bias perfectly matched!!
# model.2.cv2.bn.running_mean
# model.2.cv2.bn.running_mean perfectly matched!!
# model.2.cv2.bn.running_var
# model.2.cv2.bn.running_var perfectly matched!!
# model.2.cv2.bn.num_batches_tracked
# model.2.cv2.bn.num_batches_tracked perfectly matched!!
# model.2.cv3.conv.weight
# model.2.cv3.conv.weight perfectly matched!!
# model.2.cv3.bn.weight
# model.2.cv3.bn.weight perfectly matched!!
# model.2.cv3.bn.bias
# model.2.cv3.bn.bias perfectly matched!!
# model.2.cv3.bn.running_mean
# model.2.cv3.bn.running_mean perfectly matched!!
# model.2.cv3.bn.running_var
# model.2.cv3.bn.running_var perfectly matched!!
# model.2.cv3.bn.num_batches_tracked
# model.2.cv3.bn.num_batches_tracked perfectly matched!!
# model.2.cv4.conv.weight
# model.2.cv4.conv.weight perfectly matched!!
# model.2.cv4.bn.weight
# model.2.cv4.bn.weight perfectly matched!!
# model.2.cv4.bn.bias
# model.2.cv4.bn.bias perfectly matched!!
# model.2.cv4.bn.running_mean
# model.2.cv4.bn.running_mean perfectly matched!!
# model.2.cv4.bn.running_var
# model.2.cv4.bn.running_var perfectly matched!!
# model.2.cv4.bn.num_batches_tracked
# model.2.cv4.bn.num_batches_tracked perfectly matched!!
# model.3.cv1.conv.weight
# model.3.cv1.conv.weight perfectly matched!!
# model.3.cv1.bn.weight
# model.3.cv1.bn.weight perfectly matched!!
# model.3.cv1.bn.bias
# model.3.cv1.bn.bias perfectly matched!!
# model.3.cv1.bn.running_mean
# model.3.cv1.bn.running_mean perfectly matched!!
# model.3.cv1.bn.running_var
# model.3.cv1.bn.running_var perfectly matched!!
# model.3.cv1.bn.num_batches_tracked
# model.3.cv1.bn.num_batches_tracked perfectly matched!!
# model.4.cv1.conv.weight
# model.4.cv1.conv.weight perfectly matched!!
# model.4.cv1.bn.weight
# model.4.cv1.bn.weight perfectly matched!!
# model.4.cv1.bn.bias
# model.4.cv1.bn.bias perfectly matched!!
# model.4.cv1.bn.running_mean
# model.4.cv1.bn.running_mean perfectly matched!!
# model.4.cv1.bn.running_var
# model.4.cv1.bn.running_var perfectly matched!!
# model.4.cv1.bn.num_batches_tracked
# model.4.cv1.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.cv1.conv.weight
# model.4.cv2.0.cv1.conv.weight perfectly matched!!
# model.4.cv2.0.cv1.bn.weight
# model.4.cv2.0.cv1.bn.weight perfectly matched!!
# model.4.cv2.0.cv1.bn.bias
# model.4.cv2.0.cv1.bn.bias perfectly matched!!
# model.4.cv2.0.cv1.bn.running_mean
# model.4.cv2.0.cv1.bn.running_mean perfectly matched!!
# model.4.cv2.0.cv1.bn.running_var
# model.4.cv2.0.cv1.bn.running_var perfectly matched!!
# model.4.cv2.0.cv1.bn.num_batches_tracked
# model.4.cv2.0.cv1.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.cv2.conv.weight
# model.4.cv2.0.cv2.conv.weight perfectly matched!!
# model.4.cv2.0.cv2.bn.weight
# model.4.cv2.0.cv2.bn.weight perfectly matched!!
# model.4.cv2.0.cv2.bn.bias
# model.4.cv2.0.cv2.bn.bias perfectly matched!!
# model.4.cv2.0.cv2.bn.running_mean
# model.4.cv2.0.cv2.bn.running_mean perfectly matched!!
# model.4.cv2.0.cv2.bn.running_var
# model.4.cv2.0.cv2.bn.running_var perfectly matched!!
# model.4.cv2.0.cv2.bn.num_batches_tracked
# model.4.cv2.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.cv3.conv.weight
# model.4.cv2.0.cv3.conv.weight perfectly matched!!
# model.4.cv2.0.cv3.bn.weight
# model.4.cv2.0.cv3.bn.weight perfectly matched!!
# model.4.cv2.0.cv3.bn.bias
# model.4.cv2.0.cv3.bn.bias perfectly matched!!
# model.4.cv2.0.cv3.bn.running_mean
# model.4.cv2.0.cv3.bn.running_mean perfectly matched!!
# model.4.cv2.0.cv3.bn.running_var
# model.4.cv2.0.cv3.bn.running_var perfectly matched!!
# model.4.cv2.0.cv3.bn.num_batches_tracked
# model.4.cv2.0.cv3.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv1.conv.weight
# model.4.cv2.0.m.0.cv1.conv1.conv.weight perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv1.bn.weight
# model.4.cv2.0.m.0.cv1.conv1.bn.weight perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv1.bn.bias
# model.4.cv2.0.m.0.cv1.conv1.bn.bias perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv1.bn.running_mean
# model.4.cv2.0.m.0.cv1.conv1.bn.running_mean perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv1.bn.running_var
# model.4.cv2.0.m.0.cv1.conv1.bn.running_var perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv1.bn.num_batches_tracked
# model.4.cv2.0.m.0.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv2.conv.weight
# model.4.cv2.0.m.0.cv1.conv2.conv.weight perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv2.bn.weight
# model.4.cv2.0.m.0.cv1.conv2.bn.weight perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv2.bn.bias
# model.4.cv2.0.m.0.cv1.conv2.bn.bias perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv2.bn.running_mean
# model.4.cv2.0.m.0.cv1.conv2.bn.running_mean perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv2.bn.running_var
# model.4.cv2.0.m.0.cv1.conv2.bn.running_var perfectly matched!!
# model.4.cv2.0.m.0.cv1.conv2.bn.num_batches_tracked
# model.4.cv2.0.m.0.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.m.0.cv2.conv.weight
# model.4.cv2.0.m.0.cv2.conv.weight perfectly matched!!
# model.4.cv2.0.m.0.cv2.bn.weight
# model.4.cv2.0.m.0.cv2.bn.weight perfectly matched!!
# model.4.cv2.0.m.0.cv2.bn.bias
# model.4.cv2.0.m.0.cv2.bn.bias perfectly matched!!
# model.4.cv2.0.m.0.cv2.bn.running_mean
# model.4.cv2.0.m.0.cv2.bn.running_mean perfectly matched!!
# model.4.cv2.0.m.0.cv2.bn.running_var
# model.4.cv2.0.m.0.cv2.bn.running_var perfectly matched!!
# model.4.cv2.0.m.0.cv2.bn.num_batches_tracked
# model.4.cv2.0.m.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv1.conv.weight
# model.4.cv2.0.m.1.cv1.conv1.conv.weight perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv1.bn.weight
# model.4.cv2.0.m.1.cv1.conv1.bn.weight perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv1.bn.bias
# model.4.cv2.0.m.1.cv1.conv1.bn.bias perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv1.bn.running_mean
# model.4.cv2.0.m.1.cv1.conv1.bn.running_mean perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv1.bn.running_var
# model.4.cv2.0.m.1.cv1.conv1.bn.running_var perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv1.bn.num_batches_tracked
# model.4.cv2.0.m.1.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv2.conv.weight
# model.4.cv2.0.m.1.cv1.conv2.conv.weight perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv2.bn.weight
# model.4.cv2.0.m.1.cv1.conv2.bn.weight perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv2.bn.bias
# model.4.cv2.0.m.1.cv1.conv2.bn.bias perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv2.bn.running_mean
# model.4.cv2.0.m.1.cv1.conv2.bn.running_mean perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv2.bn.running_var
# model.4.cv2.0.m.1.cv1.conv2.bn.running_var perfectly matched!!
# model.4.cv2.0.m.1.cv1.conv2.bn.num_batches_tracked
# model.4.cv2.0.m.1.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.m.1.cv2.conv.weight
# model.4.cv2.0.m.1.cv2.conv.weight perfectly matched!!
# model.4.cv2.0.m.1.cv2.bn.weight
# model.4.cv2.0.m.1.cv2.bn.weight perfectly matched!!
# model.4.cv2.0.m.1.cv2.bn.bias
# model.4.cv2.0.m.1.cv2.bn.bias perfectly matched!!
# model.4.cv2.0.m.1.cv2.bn.running_mean
# model.4.cv2.0.m.1.cv2.bn.running_mean perfectly matched!!
# model.4.cv2.0.m.1.cv2.bn.running_var
# model.4.cv2.0.m.1.cv2.bn.running_var perfectly matched!!
# model.4.cv2.0.m.1.cv2.bn.num_batches_tracked
# model.4.cv2.0.m.1.cv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv1.conv.weight
# model.4.cv2.0.m.2.cv1.conv1.conv.weight perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv1.bn.weight
# model.4.cv2.0.m.2.cv1.conv1.bn.weight perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv1.bn.bias
# model.4.cv2.0.m.2.cv1.conv1.bn.bias perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv1.bn.running_mean
# model.4.cv2.0.m.2.cv1.conv1.bn.running_mean perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv1.bn.running_var
# model.4.cv2.0.m.2.cv1.conv1.bn.running_var perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv1.bn.num_batches_tracked
# model.4.cv2.0.m.2.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv2.conv.weight
# model.4.cv2.0.m.2.cv1.conv2.conv.weight perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv2.bn.weight
# model.4.cv2.0.m.2.cv1.conv2.bn.weight perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv2.bn.bias
# model.4.cv2.0.m.2.cv1.conv2.bn.bias perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv2.bn.running_mean
# model.4.cv2.0.m.2.cv1.conv2.bn.running_mean perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv2.bn.running_var
# model.4.cv2.0.m.2.cv1.conv2.bn.running_var perfectly matched!!
# model.4.cv2.0.m.2.cv1.conv2.bn.num_batches_tracked
# model.4.cv2.0.m.2.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.0.m.2.cv2.conv.weight
# model.4.cv2.0.m.2.cv2.conv.weight perfectly matched!!
# model.4.cv2.0.m.2.cv2.bn.weight
# model.4.cv2.0.m.2.cv2.bn.weight perfectly matched!!
# model.4.cv2.0.m.2.cv2.bn.bias
# model.4.cv2.0.m.2.cv2.bn.bias perfectly matched!!
# model.4.cv2.0.m.2.cv2.bn.running_mean
# model.4.cv2.0.m.2.cv2.bn.running_mean perfectly matched!!
# model.4.cv2.0.m.2.cv2.bn.running_var
# model.4.cv2.0.m.2.cv2.bn.running_var perfectly matched!!
# model.4.cv2.0.m.2.cv2.bn.num_batches_tracked
# model.4.cv2.0.m.2.cv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv2.1.conv.weight
# model.4.cv2.1.conv.weight perfectly matched!!
# model.4.cv2.1.bn.weight
# model.4.cv2.1.bn.weight perfectly matched!!
# model.4.cv2.1.bn.bias
# model.4.cv2.1.bn.bias perfectly matched!!
# model.4.cv2.1.bn.running_mean
# model.4.cv2.1.bn.running_mean perfectly matched!!
# model.4.cv2.1.bn.running_var
# model.4.cv2.1.bn.running_var perfectly matched!!
# model.4.cv2.1.bn.num_batches_tracked
# model.4.cv2.1.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.cv1.conv.weight
# model.4.cv3.0.cv1.conv.weight perfectly matched!!
# model.4.cv3.0.cv1.bn.weight
# model.4.cv3.0.cv1.bn.weight perfectly matched!!
# model.4.cv3.0.cv1.bn.bias
# model.4.cv3.0.cv1.bn.bias perfectly matched!!
# model.4.cv3.0.cv1.bn.running_mean
# model.4.cv3.0.cv1.bn.running_mean perfectly matched!!
# model.4.cv3.0.cv1.bn.running_var
# model.4.cv3.0.cv1.bn.running_var perfectly matched!!
# model.4.cv3.0.cv1.bn.num_batches_tracked
# model.4.cv3.0.cv1.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.cv2.conv.weight
# model.4.cv3.0.cv2.conv.weight perfectly matched!!
# model.4.cv3.0.cv2.bn.weight
# model.4.cv3.0.cv2.bn.weight perfectly matched!!
# model.4.cv3.0.cv2.bn.bias
# model.4.cv3.0.cv2.bn.bias perfectly matched!!
# model.4.cv3.0.cv2.bn.running_mean
# model.4.cv3.0.cv2.bn.running_mean perfectly matched!!
# model.4.cv3.0.cv2.bn.running_var
# model.4.cv3.0.cv2.bn.running_var perfectly matched!!
# model.4.cv3.0.cv2.bn.num_batches_tracked
# model.4.cv3.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.cv3.conv.weight
# model.4.cv3.0.cv3.conv.weight perfectly matched!!
# model.4.cv3.0.cv3.bn.weight
# model.4.cv3.0.cv3.bn.weight perfectly matched!!
# model.4.cv3.0.cv3.bn.bias
# model.4.cv3.0.cv3.bn.bias perfectly matched!!
# model.4.cv3.0.cv3.bn.running_mean
# model.4.cv3.0.cv3.bn.running_mean perfectly matched!!
# model.4.cv3.0.cv3.bn.running_var
# model.4.cv3.0.cv3.bn.running_var perfectly matched!!
# model.4.cv3.0.cv3.bn.num_batches_tracked
# model.4.cv3.0.cv3.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv1.conv.weight
# model.4.cv3.0.m.0.cv1.conv1.conv.weight perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv1.bn.weight
# model.4.cv3.0.m.0.cv1.conv1.bn.weight perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv1.bn.bias
# model.4.cv3.0.m.0.cv1.conv1.bn.bias perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv1.bn.running_mean
# model.4.cv3.0.m.0.cv1.conv1.bn.running_mean perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv1.bn.running_var
# model.4.cv3.0.m.0.cv1.conv1.bn.running_var perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv1.bn.num_batches_tracked
# model.4.cv3.0.m.0.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv2.conv.weight
# model.4.cv3.0.m.0.cv1.conv2.conv.weight perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv2.bn.weight
# model.4.cv3.0.m.0.cv1.conv2.bn.weight perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv2.bn.bias
# model.4.cv3.0.m.0.cv1.conv2.bn.bias perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv2.bn.running_mean
# model.4.cv3.0.m.0.cv1.conv2.bn.running_mean perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv2.bn.running_var
# model.4.cv3.0.m.0.cv1.conv2.bn.running_var perfectly matched!!
# model.4.cv3.0.m.0.cv1.conv2.bn.num_batches_tracked
# model.4.cv3.0.m.0.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.m.0.cv2.conv.weight
# model.4.cv3.0.m.0.cv2.conv.weight perfectly matched!!
# model.4.cv3.0.m.0.cv2.bn.weight
# model.4.cv3.0.m.0.cv2.bn.weight perfectly matched!!
# model.4.cv3.0.m.0.cv2.bn.bias
# model.4.cv3.0.m.0.cv2.bn.bias perfectly matched!!
# model.4.cv3.0.m.0.cv2.bn.running_mean
# model.4.cv3.0.m.0.cv2.bn.running_mean perfectly matched!!
# model.4.cv3.0.m.0.cv2.bn.running_var
# model.4.cv3.0.m.0.cv2.bn.running_var perfectly matched!!
# model.4.cv3.0.m.0.cv2.bn.num_batches_tracked
# model.4.cv3.0.m.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv1.conv.weight
# model.4.cv3.0.m.1.cv1.conv1.conv.weight perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv1.bn.weight
# model.4.cv3.0.m.1.cv1.conv1.bn.weight perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv1.bn.bias
# model.4.cv3.0.m.1.cv1.conv1.bn.bias perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv1.bn.running_mean
# model.4.cv3.0.m.1.cv1.conv1.bn.running_mean perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv1.bn.running_var
# model.4.cv3.0.m.1.cv1.conv1.bn.running_var perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv1.bn.num_batches_tracked
# model.4.cv3.0.m.1.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv2.conv.weight
# model.4.cv3.0.m.1.cv1.conv2.conv.weight perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv2.bn.weight
# model.4.cv3.0.m.1.cv1.conv2.bn.weight perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv2.bn.bias
# model.4.cv3.0.m.1.cv1.conv2.bn.bias perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv2.bn.running_mean
# model.4.cv3.0.m.1.cv1.conv2.bn.running_mean perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv2.bn.running_var
# model.4.cv3.0.m.1.cv1.conv2.bn.running_var perfectly matched!!
# model.4.cv3.0.m.1.cv1.conv2.bn.num_batches_tracked
# model.4.cv3.0.m.1.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.m.1.cv2.conv.weight
# model.4.cv3.0.m.1.cv2.conv.weight perfectly matched!!
# model.4.cv3.0.m.1.cv2.bn.weight
# model.4.cv3.0.m.1.cv2.bn.weight perfectly matched!!
# model.4.cv3.0.m.1.cv2.bn.bias
# model.4.cv3.0.m.1.cv2.bn.bias perfectly matched!!
# model.4.cv3.0.m.1.cv2.bn.running_mean
# model.4.cv3.0.m.1.cv2.bn.running_mean perfectly matched!!
# model.4.cv3.0.m.1.cv2.bn.running_var
# model.4.cv3.0.m.1.cv2.bn.running_var perfectly matched!!
# model.4.cv3.0.m.1.cv2.bn.num_batches_tracked
# model.4.cv3.0.m.1.cv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv1.conv.weight
# model.4.cv3.0.m.2.cv1.conv1.conv.weight perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv1.bn.weight
# model.4.cv3.0.m.2.cv1.conv1.bn.weight perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv1.bn.bias
# model.4.cv3.0.m.2.cv1.conv1.bn.bias perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv1.bn.running_mean
# model.4.cv3.0.m.2.cv1.conv1.bn.running_mean perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv1.bn.running_var
# model.4.cv3.0.m.2.cv1.conv1.bn.running_var perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv1.bn.num_batches_tracked
# model.4.cv3.0.m.2.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv2.conv.weight
# model.4.cv3.0.m.2.cv1.conv2.conv.weight perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv2.bn.weight
# model.4.cv3.0.m.2.cv1.conv2.bn.weight perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv2.bn.bias
# model.4.cv3.0.m.2.cv1.conv2.bn.bias perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv2.bn.running_mean
# model.4.cv3.0.m.2.cv1.conv2.bn.running_mean perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv2.bn.running_var
# model.4.cv3.0.m.2.cv1.conv2.bn.running_var perfectly matched!!
# model.4.cv3.0.m.2.cv1.conv2.bn.num_batches_tracked
# model.4.cv3.0.m.2.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.0.m.2.cv2.conv.weight
# model.4.cv3.0.m.2.cv2.conv.weight perfectly matched!!
# model.4.cv3.0.m.2.cv2.bn.weight
# model.4.cv3.0.m.2.cv2.bn.weight perfectly matched!!
# model.4.cv3.0.m.2.cv2.bn.bias
# model.4.cv3.0.m.2.cv2.bn.bias perfectly matched!!
# model.4.cv3.0.m.2.cv2.bn.running_mean
# model.4.cv3.0.m.2.cv2.bn.running_mean perfectly matched!!
# model.4.cv3.0.m.2.cv2.bn.running_var
# model.4.cv3.0.m.2.cv2.bn.running_var perfectly matched!!
# model.4.cv3.0.m.2.cv2.bn.num_batches_tracked
# model.4.cv3.0.m.2.cv2.bn.num_batches_tracked perfectly matched!!
# model.4.cv3.1.conv.weight
# model.4.cv3.1.conv.weight perfectly matched!!
# model.4.cv3.1.bn.weight
# model.4.cv3.1.bn.weight perfectly matched!!
# model.4.cv3.1.bn.bias
# model.4.cv3.1.bn.bias perfectly matched!!
# model.4.cv3.1.bn.running_mean
# model.4.cv3.1.bn.running_mean perfectly matched!!
# model.4.cv3.1.bn.running_var
# model.4.cv3.1.bn.running_var perfectly matched!!
# model.4.cv3.1.bn.num_batches_tracked
# model.4.cv3.1.bn.num_batches_tracked perfectly matched!!
# model.4.cv4.conv.weight
# model.4.cv4.conv.weight perfectly matched!!
# model.4.cv4.bn.weight
# model.4.cv4.bn.weight perfectly matched!!
# model.4.cv4.bn.bias
# model.4.cv4.bn.bias perfectly matched!!
# model.4.cv4.bn.running_mean
# model.4.cv4.bn.running_mean perfectly matched!!
# model.4.cv4.bn.running_var
# model.4.cv4.bn.running_var perfectly matched!!
# model.4.cv4.bn.num_batches_tracked
# model.4.cv4.bn.num_batches_tracked perfectly matched!!
# model.5.cv1.conv.weight
# model.5.cv1.conv.weight perfectly matched!!
# model.5.cv1.bn.weight
# model.5.cv1.bn.weight perfectly matched!!
# model.5.cv1.bn.bias
# model.5.cv1.bn.bias perfectly matched!!
# model.5.cv1.bn.running_mean
# model.5.cv1.bn.running_mean perfectly matched!!
# model.5.cv1.bn.running_var
# model.5.cv1.bn.running_var perfectly matched!!
# model.5.cv1.bn.num_batches_tracked
# model.5.cv1.bn.num_batches_tracked perfectly matched!!
# model.6.cv1.conv.weight
# model.6.cv1.conv.weight perfectly matched!!
# model.6.cv1.bn.weight
# model.6.cv1.bn.weight perfectly matched!!
# model.6.cv1.bn.bias
# model.6.cv1.bn.bias perfectly matched!!
# model.6.cv1.bn.running_mean
# model.6.cv1.bn.running_mean perfectly matched!!
# model.6.cv1.bn.running_var
# model.6.cv1.bn.running_var perfectly matched!!
# model.6.cv1.bn.num_batches_tracked
# model.6.cv1.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.cv1.conv.weight
# model.6.cv2.0.cv1.conv.weight perfectly matched!!
# model.6.cv2.0.cv1.bn.weight
# model.6.cv2.0.cv1.bn.weight perfectly matched!!
# model.6.cv2.0.cv1.bn.bias
# model.6.cv2.0.cv1.bn.bias perfectly matched!!
# model.6.cv2.0.cv1.bn.running_mean
# model.6.cv2.0.cv1.bn.running_mean perfectly matched!!
# model.6.cv2.0.cv1.bn.running_var
# model.6.cv2.0.cv1.bn.running_var perfectly matched!!
# model.6.cv2.0.cv1.bn.num_batches_tracked
# model.6.cv2.0.cv1.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.cv2.conv.weight
# model.6.cv2.0.cv2.conv.weight perfectly matched!!
# model.6.cv2.0.cv2.bn.weight
# model.6.cv2.0.cv2.bn.weight perfectly matched!!
# model.6.cv2.0.cv2.bn.bias
# model.6.cv2.0.cv2.bn.bias perfectly matched!!
# model.6.cv2.0.cv2.bn.running_mean
# model.6.cv2.0.cv2.bn.running_mean perfectly matched!!
# model.6.cv2.0.cv2.bn.running_var
# model.6.cv2.0.cv2.bn.running_var perfectly matched!!
# model.6.cv2.0.cv2.bn.num_batches_tracked
# model.6.cv2.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.cv3.conv.weight
# model.6.cv2.0.cv3.conv.weight perfectly matched!!
# model.6.cv2.0.cv3.bn.weight
# model.6.cv2.0.cv3.bn.weight perfectly matched!!
# model.6.cv2.0.cv3.bn.bias
# model.6.cv2.0.cv3.bn.bias perfectly matched!!
# model.6.cv2.0.cv3.bn.running_mean
# model.6.cv2.0.cv3.bn.running_mean perfectly matched!!
# model.6.cv2.0.cv3.bn.running_var
# model.6.cv2.0.cv3.bn.running_var perfectly matched!!
# model.6.cv2.0.cv3.bn.num_batches_tracked
# model.6.cv2.0.cv3.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv1.conv.weight
# model.6.cv2.0.m.0.cv1.conv1.conv.weight perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv1.bn.weight
# model.6.cv2.0.m.0.cv1.conv1.bn.weight perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv1.bn.bias
# model.6.cv2.0.m.0.cv1.conv1.bn.bias perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv1.bn.running_mean
# model.6.cv2.0.m.0.cv1.conv1.bn.running_mean perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv1.bn.running_var
# model.6.cv2.0.m.0.cv1.conv1.bn.running_var perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv1.bn.num_batches_tracked
# model.6.cv2.0.m.0.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv2.conv.weight
# model.6.cv2.0.m.0.cv1.conv2.conv.weight perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv2.bn.weight
# model.6.cv2.0.m.0.cv1.conv2.bn.weight perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv2.bn.bias
# model.6.cv2.0.m.0.cv1.conv2.bn.bias perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv2.bn.running_mean
# model.6.cv2.0.m.0.cv1.conv2.bn.running_mean perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv2.bn.running_var
# model.6.cv2.0.m.0.cv1.conv2.bn.running_var perfectly matched!!
# model.6.cv2.0.m.0.cv1.conv2.bn.num_batches_tracked
# model.6.cv2.0.m.0.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.m.0.cv2.conv.weight
# model.6.cv2.0.m.0.cv2.conv.weight perfectly matched!!
# model.6.cv2.0.m.0.cv2.bn.weight
# model.6.cv2.0.m.0.cv2.bn.weight perfectly matched!!
# model.6.cv2.0.m.0.cv2.bn.bias
# model.6.cv2.0.m.0.cv2.bn.bias perfectly matched!!
# model.6.cv2.0.m.0.cv2.bn.running_mean
# model.6.cv2.0.m.0.cv2.bn.running_mean perfectly matched!!
# model.6.cv2.0.m.0.cv2.bn.running_var
# model.6.cv2.0.m.0.cv2.bn.running_var perfectly matched!!
# model.6.cv2.0.m.0.cv2.bn.num_batches_tracked
# model.6.cv2.0.m.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv1.conv.weight
# model.6.cv2.0.m.1.cv1.conv1.conv.weight perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv1.bn.weight
# model.6.cv2.0.m.1.cv1.conv1.bn.weight perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv1.bn.bias
# model.6.cv2.0.m.1.cv1.conv1.bn.bias perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv1.bn.running_mean
# model.6.cv2.0.m.1.cv1.conv1.bn.running_mean perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv1.bn.running_var
# model.6.cv2.0.m.1.cv1.conv1.bn.running_var perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv1.bn.num_batches_tracked
# model.6.cv2.0.m.1.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv2.conv.weight
# model.6.cv2.0.m.1.cv1.conv2.conv.weight perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv2.bn.weight
# model.6.cv2.0.m.1.cv1.conv2.bn.weight perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv2.bn.bias
# model.6.cv2.0.m.1.cv1.conv2.bn.bias perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv2.bn.running_mean
# model.6.cv2.0.m.1.cv1.conv2.bn.running_mean perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv2.bn.running_var
# model.6.cv2.0.m.1.cv1.conv2.bn.running_var perfectly matched!!
# model.6.cv2.0.m.1.cv1.conv2.bn.num_batches_tracked
# model.6.cv2.0.m.1.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.m.1.cv2.conv.weight
# model.6.cv2.0.m.1.cv2.conv.weight perfectly matched!!
# model.6.cv2.0.m.1.cv2.bn.weight
# model.6.cv2.0.m.1.cv2.bn.weight perfectly matched!!
# model.6.cv2.0.m.1.cv2.bn.bias
# model.6.cv2.0.m.1.cv2.bn.bias perfectly matched!!
# model.6.cv2.0.m.1.cv2.bn.running_mean
# model.6.cv2.0.m.1.cv2.bn.running_mean perfectly matched!!
# model.6.cv2.0.m.1.cv2.bn.running_var
# model.6.cv2.0.m.1.cv2.bn.running_var perfectly matched!!
# model.6.cv2.0.m.1.cv2.bn.num_batches_tracked
# model.6.cv2.0.m.1.cv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv1.conv.weight
# model.6.cv2.0.m.2.cv1.conv1.conv.weight perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv1.bn.weight
# model.6.cv2.0.m.2.cv1.conv1.bn.weight perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv1.bn.bias
# model.6.cv2.0.m.2.cv1.conv1.bn.bias perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv1.bn.running_mean
# model.6.cv2.0.m.2.cv1.conv1.bn.running_mean perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv1.bn.running_var
# model.6.cv2.0.m.2.cv1.conv1.bn.running_var perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv1.bn.num_batches_tracked
# model.6.cv2.0.m.2.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv2.conv.weight
# model.6.cv2.0.m.2.cv1.conv2.conv.weight perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv2.bn.weight
# model.6.cv2.0.m.2.cv1.conv2.bn.weight perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv2.bn.bias
# model.6.cv2.0.m.2.cv1.conv2.bn.bias perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv2.bn.running_mean
# model.6.cv2.0.m.2.cv1.conv2.bn.running_mean perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv2.bn.running_var
# model.6.cv2.0.m.2.cv1.conv2.bn.running_var perfectly matched!!
# model.6.cv2.0.m.2.cv1.conv2.bn.num_batches_tracked
# model.6.cv2.0.m.2.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.0.m.2.cv2.conv.weight
# model.6.cv2.0.m.2.cv2.conv.weight perfectly matched!!
# model.6.cv2.0.m.2.cv2.bn.weight
# model.6.cv2.0.m.2.cv2.bn.weight perfectly matched!!
# model.6.cv2.0.m.2.cv2.bn.bias
# model.6.cv2.0.m.2.cv2.bn.bias perfectly matched!!
# model.6.cv2.0.m.2.cv2.bn.running_mean
# model.6.cv2.0.m.2.cv2.bn.running_mean perfectly matched!!
# model.6.cv2.0.m.2.cv2.bn.running_var
# model.6.cv2.0.m.2.cv2.bn.running_var perfectly matched!!
# model.6.cv2.0.m.2.cv2.bn.num_batches_tracked
# model.6.cv2.0.m.2.cv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv2.1.conv.weight
# model.6.cv2.1.conv.weight perfectly matched!!
# model.6.cv2.1.bn.weight
# model.6.cv2.1.bn.weight perfectly matched!!
# model.6.cv2.1.bn.bias
# model.6.cv2.1.bn.bias perfectly matched!!
# model.6.cv2.1.bn.running_mean
# model.6.cv2.1.bn.running_mean perfectly matched!!
# model.6.cv2.1.bn.running_var
# model.6.cv2.1.bn.running_var perfectly matched!!
# model.6.cv2.1.bn.num_batches_tracked
# model.6.cv2.1.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.cv1.conv.weight
# model.6.cv3.0.cv1.conv.weight perfectly matched!!
# model.6.cv3.0.cv1.bn.weight
# model.6.cv3.0.cv1.bn.weight perfectly matched!!
# model.6.cv3.0.cv1.bn.bias
# model.6.cv3.0.cv1.bn.bias perfectly matched!!
# model.6.cv3.0.cv1.bn.running_mean
# model.6.cv3.0.cv1.bn.running_mean perfectly matched!!
# model.6.cv3.0.cv1.bn.running_var
# model.6.cv3.0.cv1.bn.running_var perfectly matched!!
# model.6.cv3.0.cv1.bn.num_batches_tracked
# model.6.cv3.0.cv1.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.cv2.conv.weight
# model.6.cv3.0.cv2.conv.weight perfectly matched!!
# model.6.cv3.0.cv2.bn.weight
# model.6.cv3.0.cv2.bn.weight perfectly matched!!
# model.6.cv3.0.cv2.bn.bias
# model.6.cv3.0.cv2.bn.bias perfectly matched!!
# model.6.cv3.0.cv2.bn.running_mean
# model.6.cv3.0.cv2.bn.running_mean perfectly matched!!
# model.6.cv3.0.cv2.bn.running_var
# model.6.cv3.0.cv2.bn.running_var perfectly matched!!
# model.6.cv3.0.cv2.bn.num_batches_tracked
# model.6.cv3.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.cv3.conv.weight
# model.6.cv3.0.cv3.conv.weight perfectly matched!!
# model.6.cv3.0.cv3.bn.weight
# model.6.cv3.0.cv3.bn.weight perfectly matched!!
# model.6.cv3.0.cv3.bn.bias
# model.6.cv3.0.cv3.bn.bias perfectly matched!!
# model.6.cv3.0.cv3.bn.running_mean
# model.6.cv3.0.cv3.bn.running_mean perfectly matched!!
# model.6.cv3.0.cv3.bn.running_var
# model.6.cv3.0.cv3.bn.running_var perfectly matched!!
# model.6.cv3.0.cv3.bn.num_batches_tracked
# model.6.cv3.0.cv3.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv1.conv.weight
# model.6.cv3.0.m.0.cv1.conv1.conv.weight perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv1.bn.weight
# model.6.cv3.0.m.0.cv1.conv1.bn.weight perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv1.bn.bias
# model.6.cv3.0.m.0.cv1.conv1.bn.bias perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv1.bn.running_mean
# model.6.cv3.0.m.0.cv1.conv1.bn.running_mean perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv1.bn.running_var
# model.6.cv3.0.m.0.cv1.conv1.bn.running_var perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv1.bn.num_batches_tracked
# model.6.cv3.0.m.0.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv2.conv.weight
# model.6.cv3.0.m.0.cv1.conv2.conv.weight perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv2.bn.weight
# model.6.cv3.0.m.0.cv1.conv2.bn.weight perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv2.bn.bias
# model.6.cv3.0.m.0.cv1.conv2.bn.bias perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv2.bn.running_mean
# model.6.cv3.0.m.0.cv1.conv2.bn.running_mean perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv2.bn.running_var
# model.6.cv3.0.m.0.cv1.conv2.bn.running_var perfectly matched!!
# model.6.cv3.0.m.0.cv1.conv2.bn.num_batches_tracked
# model.6.cv3.0.m.0.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.m.0.cv2.conv.weight
# model.6.cv3.0.m.0.cv2.conv.weight perfectly matched!!
# model.6.cv3.0.m.0.cv2.bn.weight
# model.6.cv3.0.m.0.cv2.bn.weight perfectly matched!!
# model.6.cv3.0.m.0.cv2.bn.bias
# model.6.cv3.0.m.0.cv2.bn.bias perfectly matched!!
# model.6.cv3.0.m.0.cv2.bn.running_mean
# model.6.cv3.0.m.0.cv2.bn.running_mean perfectly matched!!
# model.6.cv3.0.m.0.cv2.bn.running_var
# model.6.cv3.0.m.0.cv2.bn.running_var perfectly matched!!
# model.6.cv3.0.m.0.cv2.bn.num_batches_tracked
# model.6.cv3.0.m.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv1.conv.weight
# model.6.cv3.0.m.1.cv1.conv1.conv.weight perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv1.bn.weight
# model.6.cv3.0.m.1.cv1.conv1.bn.weight perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv1.bn.bias
# model.6.cv3.0.m.1.cv1.conv1.bn.bias perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv1.bn.running_mean
# model.6.cv3.0.m.1.cv1.conv1.bn.running_mean perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv1.bn.running_var
# model.6.cv3.0.m.1.cv1.conv1.bn.running_var perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv1.bn.num_batches_tracked
# model.6.cv3.0.m.1.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv2.conv.weight
# model.6.cv3.0.m.1.cv1.conv2.conv.weight perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv2.bn.weight
# model.6.cv3.0.m.1.cv1.conv2.bn.weight perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv2.bn.bias
# model.6.cv3.0.m.1.cv1.conv2.bn.bias perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv2.bn.running_mean
# model.6.cv3.0.m.1.cv1.conv2.bn.running_mean perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv2.bn.running_var
# model.6.cv3.0.m.1.cv1.conv2.bn.running_var perfectly matched!!
# model.6.cv3.0.m.1.cv1.conv2.bn.num_batches_tracked
# model.6.cv3.0.m.1.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.m.1.cv2.conv.weight
# model.6.cv3.0.m.1.cv2.conv.weight perfectly matched!!
# model.6.cv3.0.m.1.cv2.bn.weight
# model.6.cv3.0.m.1.cv2.bn.weight perfectly matched!!
# model.6.cv3.0.m.1.cv2.bn.bias
# model.6.cv3.0.m.1.cv2.bn.bias perfectly matched!!
# model.6.cv3.0.m.1.cv2.bn.running_mean
# model.6.cv3.0.m.1.cv2.bn.running_mean perfectly matched!!
# model.6.cv3.0.m.1.cv2.bn.running_var
# model.6.cv3.0.m.1.cv2.bn.running_var perfectly matched!!
# model.6.cv3.0.m.1.cv2.bn.num_batches_tracked
# model.6.cv3.0.m.1.cv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv1.conv.weight
# model.6.cv3.0.m.2.cv1.conv1.conv.weight perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv1.bn.weight
# model.6.cv3.0.m.2.cv1.conv1.bn.weight perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv1.bn.bias
# model.6.cv3.0.m.2.cv1.conv1.bn.bias perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv1.bn.running_mean
# model.6.cv3.0.m.2.cv1.conv1.bn.running_mean perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv1.bn.running_var
# model.6.cv3.0.m.2.cv1.conv1.bn.running_var perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv1.bn.num_batches_tracked
# model.6.cv3.0.m.2.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv2.conv.weight
# model.6.cv3.0.m.2.cv1.conv2.conv.weight perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv2.bn.weight
# model.6.cv3.0.m.2.cv1.conv2.bn.weight perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv2.bn.bias
# model.6.cv3.0.m.2.cv1.conv2.bn.bias perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv2.bn.running_mean
# model.6.cv3.0.m.2.cv1.conv2.bn.running_mean perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv2.bn.running_var
# model.6.cv3.0.m.2.cv1.conv2.bn.running_var perfectly matched!!
# model.6.cv3.0.m.2.cv1.conv2.bn.num_batches_tracked
# model.6.cv3.0.m.2.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.0.m.2.cv2.conv.weight
# model.6.cv3.0.m.2.cv2.conv.weight perfectly matched!!
# model.6.cv3.0.m.2.cv2.bn.weight
# model.6.cv3.0.m.2.cv2.bn.weight perfectly matched!!
# model.6.cv3.0.m.2.cv2.bn.bias
# model.6.cv3.0.m.2.cv2.bn.bias perfectly matched!!
# model.6.cv3.0.m.2.cv2.bn.running_mean
# model.6.cv3.0.m.2.cv2.bn.running_mean perfectly matched!!
# model.6.cv3.0.m.2.cv2.bn.running_var
# model.6.cv3.0.m.2.cv2.bn.running_var perfectly matched!!
# model.6.cv3.0.m.2.cv2.bn.num_batches_tracked
# model.6.cv3.0.m.2.cv2.bn.num_batches_tracked perfectly matched!!
# model.6.cv3.1.conv.weight
# model.6.cv3.1.conv.weight perfectly matched!!
# model.6.cv3.1.bn.weight
# model.6.cv3.1.bn.weight perfectly matched!!
# model.6.cv3.1.bn.bias
# model.6.cv3.1.bn.bias perfectly matched!!
# model.6.cv3.1.bn.running_mean
# model.6.cv3.1.bn.running_mean perfectly matched!!
# model.6.cv3.1.bn.running_var
# model.6.cv3.1.bn.running_var perfectly matched!!
# model.6.cv3.1.bn.num_batches_tracked
# model.6.cv3.1.bn.num_batches_tracked perfectly matched!!
# model.6.cv4.conv.weight
# model.6.cv4.conv.weight perfectly matched!!
# model.6.cv4.bn.weight
# model.6.cv4.bn.weight perfectly matched!!
# model.6.cv4.bn.bias
# model.6.cv4.bn.bias perfectly matched!!
# model.6.cv4.bn.running_mean
# model.6.cv4.bn.running_mean perfectly matched!!
# model.6.cv4.bn.running_var
# model.6.cv4.bn.running_var perfectly matched!!
# model.6.cv4.bn.num_batches_tracked
# model.6.cv4.bn.num_batches_tracked perfectly matched!!
# model.7.cv1.conv.weight
# model.7.cv1.conv.weight perfectly matched!!
# model.7.cv1.bn.weight
# model.7.cv1.bn.weight perfectly matched!!
# model.7.cv1.bn.bias
# model.7.cv1.bn.bias perfectly matched!!
# model.7.cv1.bn.running_mean
# model.7.cv1.bn.running_mean perfectly matched!!
# model.7.cv1.bn.running_var
# model.7.cv1.bn.running_var perfectly matched!!
# model.7.cv1.bn.num_batches_tracked
# model.7.cv1.bn.num_batches_tracked perfectly matched!!
# model.8.cv1.conv.weight
# model.8.cv1.conv.weight perfectly matched!!
# model.8.cv1.bn.weight
# model.8.cv1.bn.weight perfectly matched!!
# model.8.cv1.bn.bias
# model.8.cv1.bn.bias perfectly matched!!
# model.8.cv1.bn.running_mean
# model.8.cv1.bn.running_mean perfectly matched!!
# model.8.cv1.bn.running_var
# model.8.cv1.bn.running_var perfectly matched!!
# model.8.cv1.bn.num_batches_tracked
# model.8.cv1.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.cv1.conv.weight
# model.8.cv2.0.cv1.conv.weight perfectly matched!!
# model.8.cv2.0.cv1.bn.weight
# model.8.cv2.0.cv1.bn.weight perfectly matched!!
# model.8.cv2.0.cv1.bn.bias
# model.8.cv2.0.cv1.bn.bias perfectly matched!!
# model.8.cv2.0.cv1.bn.running_mean
# model.8.cv2.0.cv1.bn.running_mean perfectly matched!!
# model.8.cv2.0.cv1.bn.running_var
# model.8.cv2.0.cv1.bn.running_var perfectly matched!!
# model.8.cv2.0.cv1.bn.num_batches_tracked
# model.8.cv2.0.cv1.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.cv2.conv.weight
# model.8.cv2.0.cv2.conv.weight perfectly matched!!
# model.8.cv2.0.cv2.bn.weight
# model.8.cv2.0.cv2.bn.weight perfectly matched!!
# model.8.cv2.0.cv2.bn.bias
# model.8.cv2.0.cv2.bn.bias perfectly matched!!
# model.8.cv2.0.cv2.bn.running_mean
# model.8.cv2.0.cv2.bn.running_mean perfectly matched!!
# model.8.cv2.0.cv2.bn.running_var
# model.8.cv2.0.cv2.bn.running_var perfectly matched!!
# model.8.cv2.0.cv2.bn.num_batches_tracked
# model.8.cv2.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.cv3.conv.weight
# model.8.cv2.0.cv3.conv.weight perfectly matched!!
# model.8.cv2.0.cv3.bn.weight
# model.8.cv2.0.cv3.bn.weight perfectly matched!!
# model.8.cv2.0.cv3.bn.bias
# model.8.cv2.0.cv3.bn.bias perfectly matched!!
# model.8.cv2.0.cv3.bn.running_mean
# model.8.cv2.0.cv3.bn.running_mean perfectly matched!!
# model.8.cv2.0.cv3.bn.running_var
# model.8.cv2.0.cv3.bn.running_var perfectly matched!!
# model.8.cv2.0.cv3.bn.num_batches_tracked
# model.8.cv2.0.cv3.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv1.conv.weight
# model.8.cv2.0.m.0.cv1.conv1.conv.weight perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv1.bn.weight
# model.8.cv2.0.m.0.cv1.conv1.bn.weight perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv1.bn.bias
# model.8.cv2.0.m.0.cv1.conv1.bn.bias perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv1.bn.running_mean
# model.8.cv2.0.m.0.cv1.conv1.bn.running_mean perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv1.bn.running_var
# model.8.cv2.0.m.0.cv1.conv1.bn.running_var perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv1.bn.num_batches_tracked
# model.8.cv2.0.m.0.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv2.conv.weight
# model.8.cv2.0.m.0.cv1.conv2.conv.weight perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv2.bn.weight
# model.8.cv2.0.m.0.cv1.conv2.bn.weight perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv2.bn.bias
# model.8.cv2.0.m.0.cv1.conv2.bn.bias perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv2.bn.running_mean
# model.8.cv2.0.m.0.cv1.conv2.bn.running_mean perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv2.bn.running_var
# model.8.cv2.0.m.0.cv1.conv2.bn.running_var perfectly matched!!
# model.8.cv2.0.m.0.cv1.conv2.bn.num_batches_tracked
# model.8.cv2.0.m.0.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.m.0.cv2.conv.weight
# model.8.cv2.0.m.0.cv2.conv.weight perfectly matched!!
# model.8.cv2.0.m.0.cv2.bn.weight
# model.8.cv2.0.m.0.cv2.bn.weight perfectly matched!!
# model.8.cv2.0.m.0.cv2.bn.bias
# model.8.cv2.0.m.0.cv2.bn.bias perfectly matched!!
# model.8.cv2.0.m.0.cv2.bn.running_mean
# model.8.cv2.0.m.0.cv2.bn.running_mean perfectly matched!!
# model.8.cv2.0.m.0.cv2.bn.running_var
# model.8.cv2.0.m.0.cv2.bn.running_var perfectly matched!!
# model.8.cv2.0.m.0.cv2.bn.num_batches_tracked
# model.8.cv2.0.m.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv1.conv.weight
# model.8.cv2.0.m.1.cv1.conv1.conv.weight perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv1.bn.weight
# model.8.cv2.0.m.1.cv1.conv1.bn.weight perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv1.bn.bias
# model.8.cv2.0.m.1.cv1.conv1.bn.bias perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv1.bn.running_mean
# model.8.cv2.0.m.1.cv1.conv1.bn.running_mean perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv1.bn.running_var
# model.8.cv2.0.m.1.cv1.conv1.bn.running_var perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv1.bn.num_batches_tracked
# model.8.cv2.0.m.1.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv2.conv.weight
# model.8.cv2.0.m.1.cv1.conv2.conv.weight perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv2.bn.weight
# model.8.cv2.0.m.1.cv1.conv2.bn.weight perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv2.bn.bias
# model.8.cv2.0.m.1.cv1.conv2.bn.bias perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv2.bn.running_mean
# model.8.cv2.0.m.1.cv1.conv2.bn.running_mean perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv2.bn.running_var
# model.8.cv2.0.m.1.cv1.conv2.bn.running_var perfectly matched!!
# model.8.cv2.0.m.1.cv1.conv2.bn.num_batches_tracked
# model.8.cv2.0.m.1.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.m.1.cv2.conv.weight
# model.8.cv2.0.m.1.cv2.conv.weight perfectly matched!!
# model.8.cv2.0.m.1.cv2.bn.weight
# model.8.cv2.0.m.1.cv2.bn.weight perfectly matched!!
# model.8.cv2.0.m.1.cv2.bn.bias
# model.8.cv2.0.m.1.cv2.bn.bias perfectly matched!!
# model.8.cv2.0.m.1.cv2.bn.running_mean
# model.8.cv2.0.m.1.cv2.bn.running_mean perfectly matched!!
# model.8.cv2.0.m.1.cv2.bn.running_var
# model.8.cv2.0.m.1.cv2.bn.running_var perfectly matched!!
# model.8.cv2.0.m.1.cv2.bn.num_batches_tracked
# model.8.cv2.0.m.1.cv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv1.conv.weight
# model.8.cv2.0.m.2.cv1.conv1.conv.weight perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv1.bn.weight
# model.8.cv2.0.m.2.cv1.conv1.bn.weight perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv1.bn.bias
# model.8.cv2.0.m.2.cv1.conv1.bn.bias perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv1.bn.running_mean
# model.8.cv2.0.m.2.cv1.conv1.bn.running_mean perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv1.bn.running_var
# model.8.cv2.0.m.2.cv1.conv1.bn.running_var perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv1.bn.num_batches_tracked
# model.8.cv2.0.m.2.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv2.conv.weight
# model.8.cv2.0.m.2.cv1.conv2.conv.weight perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv2.bn.weight
# model.8.cv2.0.m.2.cv1.conv2.bn.weight perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv2.bn.bias
# model.8.cv2.0.m.2.cv1.conv2.bn.bias perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv2.bn.running_mean
# model.8.cv2.0.m.2.cv1.conv2.bn.running_mean perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv2.bn.running_var
# model.8.cv2.0.m.2.cv1.conv2.bn.running_var perfectly matched!!
# model.8.cv2.0.m.2.cv1.conv2.bn.num_batches_tracked
# model.8.cv2.0.m.2.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.0.m.2.cv2.conv.weight
# model.8.cv2.0.m.2.cv2.conv.weight perfectly matched!!
# model.8.cv2.0.m.2.cv2.bn.weight
# model.8.cv2.0.m.2.cv2.bn.weight perfectly matched!!
# model.8.cv2.0.m.2.cv2.bn.bias
# model.8.cv2.0.m.2.cv2.bn.bias perfectly matched!!
# model.8.cv2.0.m.2.cv2.bn.running_mean
# model.8.cv2.0.m.2.cv2.bn.running_mean perfectly matched!!
# model.8.cv2.0.m.2.cv2.bn.running_var
# model.8.cv2.0.m.2.cv2.bn.running_var perfectly matched!!
# model.8.cv2.0.m.2.cv2.bn.num_batches_tracked
# model.8.cv2.0.m.2.cv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv2.1.conv.weight
# model.8.cv2.1.conv.weight perfectly matched!!
# model.8.cv2.1.bn.weight
# model.8.cv2.1.bn.weight perfectly matched!!
# model.8.cv2.1.bn.bias
# model.8.cv2.1.bn.bias perfectly matched!!
# model.8.cv2.1.bn.running_mean
# model.8.cv2.1.bn.running_mean perfectly matched!!
# model.8.cv2.1.bn.running_var
# model.8.cv2.1.bn.running_var perfectly matched!!
# model.8.cv2.1.bn.num_batches_tracked
# model.8.cv2.1.bn.num_batches_tracked perfectly matched!!
# model.8.cv3.0.cv1.conv.weight
# model.8.cv3.0.cv1.conv.weight perfectly matched!!
# model.8.cv3.0.cv1.bn.weight
# model.8.cv3.0.cv1.bn.weight perfectly matched!!
# model.8.cv3.0.cv1.bn.bias
# model.8.cv3.0.cv1.bn.bias perfectly matched!!
# model.8.cv3.0.cv1.bn.running_mean
# model.8.cv3.0.cv1.bn.running_mean perfectly matched!!
# model.8.cv3.0.cv1.bn.running_var
# model.8.cv3.0.cv1.bn.running_var perfectly matched!!
# model.8.cv3.0.cv1.bn.num_batches_tracked
# model.8.cv3.0.cv1.bn.num_batches_tracked perfectly matched!!
# model.8.cv3.0.cv2.conv.weight
# model.8.cv3.0.cv2.conv.weight perfectly matched!!
# model.8.cv3.0.cv2.bn.weight
# model.8.cv3.0.cv2.bn.weight perfectly matched!!
# model.8.cv3.0.cv2.bn.bias
# model.8.cv3.0.cv2.bn.bias perfectly matched!!
# model.8.cv3.0.cv2.bn.running_mean
# model.8.cv3.0.cv2.bn.running_mean perfectly matched!!
# model.8.cv3.0.cv2.bn.running_var
# model.8.cv3.0.cv2.bn.running_var perfectly matched!!
# model.8.cv3.0.cv2.bn.num_batches_tracked
# model.8.cv3.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv3.0.cv3.conv.weight
# model.8.cv3.0.cv3.conv.weight perfectly matched!!
# model.8.cv3.0.cv3.bn.weight
# model.8.cv3.0.cv3.bn.weight perfectly matched!!
# model.8.cv3.0.cv3.bn.bias
# model.8.cv3.0.cv3.bn.bias perfectly matched!!
# model.8.cv3.0.cv3.bn.running_mean
# model.8.cv3.0.cv3.bn.running_mean perfectly matched!!
# model.8.cv3.0.cv3.bn.running_var
# model.8.cv3.0.cv3.bn.running_var perfectly matched!!
# model.8.cv3.0.cv3.bn.num_batches_tracked
# model.8.cv3.0.cv3.bn.num_batches_tracked perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv1.conv.weight
# model.8.cv3.0.m.0.cv1.conv1.conv.weight perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv1.bn.weight
# model.8.cv3.0.m.0.cv1.conv1.bn.weight perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv1.bn.bias
# model.8.cv3.0.m.0.cv1.conv1.bn.bias perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv1.bn.running_mean
# model.8.cv3.0.m.0.cv1.conv1.bn.running_mean perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv1.bn.running_var
# model.8.cv3.0.m.0.cv1.conv1.bn.running_var perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv1.bn.num_batches_tracked
# model.8.cv3.0.m.0.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv2.conv.weight
# model.8.cv3.0.m.0.cv1.conv2.conv.weight perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv2.bn.weight
# model.8.cv3.0.m.0.cv1.conv2.bn.weight perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv2.bn.bias
# model.8.cv3.0.m.0.cv1.conv2.bn.bias perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv2.bn.running_mean
# model.8.cv3.0.m.0.cv1.conv2.bn.running_mean perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv2.bn.running_var
# model.8.cv3.0.m.0.cv1.conv2.bn.running_var perfectly matched!!
# model.8.cv3.0.m.0.cv1.conv2.bn.num_batches_tracked
# model.8.cv3.0.m.0.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv3.0.m.0.cv2.conv.weight
# model.8.cv3.0.m.0.cv2.conv.weight perfectly matched!!
# model.8.cv3.0.m.0.cv2.bn.weight
# model.8.cv3.0.m.0.cv2.bn.weight perfectly matched!!
# model.8.cv3.0.m.0.cv2.bn.bias
# model.8.cv3.0.m.0.cv2.bn.bias perfectly matched!!
# model.8.cv3.0.m.0.cv2.bn.running_mean
# model.8.cv3.0.m.0.cv2.bn.running_mean perfectly matched!!
# model.8.cv3.0.m.0.cv2.bn.running_var
# model.8.cv3.0.m.0.cv2.bn.running_var perfectly matched!!
# model.8.cv3.0.m.0.cv2.bn.num_batches_tracked
# model.8.cv3.0.m.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv1.conv.weight
# model.8.cv3.0.m.1.cv1.conv1.conv.weight perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv1.bn.weight
# model.8.cv3.0.m.1.cv1.conv1.bn.weight perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv1.bn.bias
# model.8.cv3.0.m.1.cv1.conv1.bn.bias perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv1.bn.running_mean
# model.8.cv3.0.m.1.cv1.conv1.bn.running_mean perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv1.bn.running_var
# model.8.cv3.0.m.1.cv1.conv1.bn.running_var perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv1.bn.num_batches_tracked
# model.8.cv3.0.m.1.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv2.conv.weight
# model.8.cv3.0.m.1.cv1.conv2.conv.weight perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv2.bn.weight
# model.8.cv3.0.m.1.cv1.conv2.bn.weight perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv2.bn.bias
# model.8.cv3.0.m.1.cv1.conv2.bn.bias perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv2.bn.running_mean
# model.8.cv3.0.m.1.cv1.conv2.bn.running_mean perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv2.bn.running_var
# model.8.cv3.0.m.1.cv1.conv2.bn.running_var perfectly matched!!
# model.8.cv3.0.m.1.cv1.conv2.bn.num_batches_tracked
# model.8.cv3.0.m.1.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv3.0.m.1.cv2.conv.weight
# model.8.cv3.0.m.1.cv2.conv.weight perfectly matched!!
# model.8.cv3.0.m.1.cv2.bn.weight
# model.8.cv3.0.m.1.cv2.bn.weight perfectly matched!!
# model.8.cv3.0.m.1.cv2.bn.bias
# model.8.cv3.0.m.1.cv2.bn.bias perfectly matched!!
# model.8.cv3.0.m.1.cv2.bn.running_mean
# model.8.cv3.0.m.1.cv2.bn.running_mean perfectly matched!!
# model.8.cv3.0.m.1.cv2.bn.running_var
# model.8.cv3.0.m.1.cv2.bn.running_var perfectly matched!!
# model.8.cv3.0.m.1.cv2.bn.num_batches_tracked
# model.8.cv3.0.m.1.cv2.bn.num_batches_tracked perfectly matched!!
# model.8.cv3.0.m.2.cv1.conv1.conv.weight
# ...
# model.21.cv2.0.m.2.cv1.conv2.bn.running_var
# model.21.cv2.0.m.2.cv1.conv2.bn.running_var perfectly matched!!
# model.21.cv2.0.m.2.cv1.conv2.bn.num_batches_tracked
# model.21.cv2.0.m.2.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.21.cv2.0.m.2.cv2.conv.weight
# model.21.cv2.0.m.2.cv2.conv.weight perfectly matched!!
# model.21.cv2.0.m.2.cv2.bn.weight
# model.21.cv2.0.m.2.cv2.bn.weight perfectly matched!!
# model.21.cv2.0.m.2.cv2.bn.bias
# model.21.cv2.0.m.2.cv2.bn.bias perfectly matched!!
# model.21.cv2.0.m.2.cv2.bn.running_mean
# model.21.cv2.0.m.2.cv2.bn.running_mean perfectly matched!!
# model.21.cv2.0.m.2.cv2.bn.running_var
# model.21.cv2.0.m.2.cv2.bn.running_var perfectly matched!!
# model.21.cv2.0.m.2.cv2.bn.num_batches_tracked
# model.21.cv2.0.m.2.cv2.bn.num_batches_tracked perfectly matched!!
# model.21.cv2.1.conv.weight
# model.21.cv2.1.conv.weight perfectly matched!!
# model.21.cv2.1.bn.weight
# model.21.cv2.1.bn.weight perfectly matched!!
# model.21.cv2.1.bn.bias
# model.21.cv2.1.bn.bias perfectly matched!!
# model.21.cv2.1.bn.running_mean
# model.21.cv2.1.bn.running_mean perfectly matched!!
# model.21.cv2.1.bn.running_var
# model.21.cv2.1.bn.running_var perfectly matched!!
# model.21.cv2.1.bn.num_batches_tracked
# model.21.cv2.1.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.cv1.conv.weight
# model.21.cv3.0.cv1.conv.weight perfectly matched!!
# model.21.cv3.0.cv1.bn.weight
# model.21.cv3.0.cv1.bn.weight perfectly matched!!
# model.21.cv3.0.cv1.bn.bias
# model.21.cv3.0.cv1.bn.bias perfectly matched!!
# model.21.cv3.0.cv1.bn.running_mean
# model.21.cv3.0.cv1.bn.running_mean perfectly matched!!
# model.21.cv3.0.cv1.bn.running_var
# model.21.cv3.0.cv1.bn.running_var perfectly matched!!
# model.21.cv3.0.cv1.bn.num_batches_tracked
# model.21.cv3.0.cv1.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.cv2.conv.weight
# model.21.cv3.0.cv2.conv.weight perfectly matched!!
# model.21.cv3.0.cv2.bn.weight
# model.21.cv3.0.cv2.bn.weight perfectly matched!!
# model.21.cv3.0.cv2.bn.bias
# model.21.cv3.0.cv2.bn.bias perfectly matched!!
# model.21.cv3.0.cv2.bn.running_mean
# model.21.cv3.0.cv2.bn.running_mean perfectly matched!!
# model.21.cv3.0.cv2.bn.running_var
# model.21.cv3.0.cv2.bn.running_var perfectly matched!!
# model.21.cv3.0.cv2.bn.num_batches_tracked
# model.21.cv3.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.cv3.conv.weight
# model.21.cv3.0.cv3.conv.weight perfectly matched!!
# model.21.cv3.0.cv3.bn.weight
# model.21.cv3.0.cv3.bn.weight perfectly matched!!
# model.21.cv3.0.cv3.bn.bias
# model.21.cv3.0.cv3.bn.bias perfectly matched!!
# model.21.cv3.0.cv3.bn.running_mean
# model.21.cv3.0.cv3.bn.running_mean perfectly matched!!
# model.21.cv3.0.cv3.bn.running_var
# model.21.cv3.0.cv3.bn.running_var perfectly matched!!
# model.21.cv3.0.cv3.bn.num_batches_tracked
# model.21.cv3.0.cv3.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv1.conv.weight
# model.21.cv3.0.m.0.cv1.conv1.conv.weight perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv1.bn.weight
# model.21.cv3.0.m.0.cv1.conv1.bn.weight perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv1.bn.bias
# model.21.cv3.0.m.0.cv1.conv1.bn.bias perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv1.bn.running_mean
# model.21.cv3.0.m.0.cv1.conv1.bn.running_mean perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv1.bn.running_var
# model.21.cv3.0.m.0.cv1.conv1.bn.running_var perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv1.bn.num_batches_tracked
# model.21.cv3.0.m.0.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv2.conv.weight
# model.21.cv3.0.m.0.cv1.conv2.conv.weight perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv2.bn.weight
# model.21.cv3.0.m.0.cv1.conv2.bn.weight perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv2.bn.bias
# model.21.cv3.0.m.0.cv1.conv2.bn.bias perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv2.bn.running_mean
# model.21.cv3.0.m.0.cv1.conv2.bn.running_mean perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv2.bn.running_var
# model.21.cv3.0.m.0.cv1.conv2.bn.running_var perfectly matched!!
# model.21.cv3.0.m.0.cv1.conv2.bn.num_batches_tracked
# model.21.cv3.0.m.0.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.m.0.cv2.conv.weight
# model.21.cv3.0.m.0.cv2.conv.weight perfectly matched!!
# model.21.cv3.0.m.0.cv2.bn.weight
# model.21.cv3.0.m.0.cv2.bn.weight perfectly matched!!
# model.21.cv3.0.m.0.cv2.bn.bias
# model.21.cv3.0.m.0.cv2.bn.bias perfectly matched!!
# model.21.cv3.0.m.0.cv2.bn.running_mean
# model.21.cv3.0.m.0.cv2.bn.running_mean perfectly matched!!
# model.21.cv3.0.m.0.cv2.bn.running_var
# model.21.cv3.0.m.0.cv2.bn.running_var perfectly matched!!
# model.21.cv3.0.m.0.cv2.bn.num_batches_tracked
# model.21.cv3.0.m.0.cv2.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv1.conv.weight
# model.21.cv3.0.m.1.cv1.conv1.conv.weight perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv1.bn.weight
# model.21.cv3.0.m.1.cv1.conv1.bn.weight perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv1.bn.bias
# model.21.cv3.0.m.1.cv1.conv1.bn.bias perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv1.bn.running_mean
# model.21.cv3.0.m.1.cv1.conv1.bn.running_mean perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv1.bn.running_var
# model.21.cv3.0.m.1.cv1.conv1.bn.running_var perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv1.bn.num_batches_tracked
# model.21.cv3.0.m.1.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv2.conv.weight
# model.21.cv3.0.m.1.cv1.conv2.conv.weight perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv2.bn.weight
# model.21.cv3.0.m.1.cv1.conv2.bn.weight perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv2.bn.bias
# model.21.cv3.0.m.1.cv1.conv2.bn.bias perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv2.bn.running_mean
# model.21.cv3.0.m.1.cv1.conv2.bn.running_mean perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv2.bn.running_var
# model.21.cv3.0.m.1.cv1.conv2.bn.running_var perfectly matched!!
# model.21.cv3.0.m.1.cv1.conv2.bn.num_batches_tracked
# model.21.cv3.0.m.1.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.m.1.cv2.conv.weight
# model.21.cv3.0.m.1.cv2.conv.weight perfectly matched!!
# model.21.cv3.0.m.1.cv2.bn.weight
# model.21.cv3.0.m.1.cv2.bn.weight perfectly matched!!
# model.21.cv3.0.m.1.cv2.bn.bias
# model.21.cv3.0.m.1.cv2.bn.bias perfectly matched!!
# model.21.cv3.0.m.1.cv2.bn.running_mean
# model.21.cv3.0.m.1.cv2.bn.running_mean perfectly matched!!
# model.21.cv3.0.m.1.cv2.bn.running_var
# model.21.cv3.0.m.1.cv2.bn.running_var perfectly matched!!
# model.21.cv3.0.m.1.cv2.bn.num_batches_tracked
# model.21.cv3.0.m.1.cv2.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv1.conv.weight
# model.21.cv3.0.m.2.cv1.conv1.conv.weight perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv1.bn.weight
# model.21.cv3.0.m.2.cv1.conv1.bn.weight perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv1.bn.bias
# model.21.cv3.0.m.2.cv1.conv1.bn.bias perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv1.bn.running_mean
# model.21.cv3.0.m.2.cv1.conv1.bn.running_mean perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv1.bn.running_var
# model.21.cv3.0.m.2.cv1.conv1.bn.running_var perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv1.bn.num_batches_tracked
# model.21.cv3.0.m.2.cv1.conv1.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv2.conv.weight
# model.21.cv3.0.m.2.cv1.conv2.conv.weight perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv2.bn.weight
# model.21.cv3.0.m.2.cv1.conv2.bn.weight perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv2.bn.bias
# model.21.cv3.0.m.2.cv1.conv2.bn.bias perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv2.bn.running_mean
# model.21.cv3.0.m.2.cv1.conv2.bn.running_mean perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv2.bn.running_var
# model.21.cv3.0.m.2.cv1.conv2.bn.running_var perfectly matched!!
# model.21.cv3.0.m.2.cv1.conv2.bn.num_batches_tracked
# model.21.cv3.0.m.2.cv1.conv2.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.0.m.2.cv2.conv.weight
# model.21.cv3.0.m.2.cv2.conv.weight perfectly matched!!
# model.21.cv3.0.m.2.cv2.bn.weight
# model.21.cv3.0.m.2.cv2.bn.weight perfectly matched!!
# model.21.cv3.0.m.2.cv2.bn.bias
# model.21.cv3.0.m.2.cv2.bn.bias perfectly matched!!
# model.21.cv3.0.m.2.cv2.bn.running_mean
# model.21.cv3.0.m.2.cv2.bn.running_mean perfectly matched!!
# model.21.cv3.0.m.2.cv2.bn.running_var
# model.21.cv3.0.m.2.cv2.bn.running_var perfectly matched!!
# model.21.cv3.0.m.2.cv2.bn.num_batches_tracked
# model.21.cv3.0.m.2.cv2.bn.num_batches_tracked perfectly matched!!
# model.21.cv3.1.conv.weight
# model.21.cv3.1.conv.weight perfectly matched!!
# model.21.cv3.1.bn.weight
# model.21.cv3.1.bn.weight perfectly matched!!
# model.21.cv3.1.bn.bias
# model.21.cv3.1.bn.bias perfectly matched!!
# model.21.cv3.1.bn.running_mean
# model.21.cv3.1.bn.running_mean perfectly matched!!
# model.21.cv3.1.bn.running_var
# model.21.cv3.1.bn.running_var perfectly matched!!
# model.21.cv3.1.bn.num_batches_tracked
# model.21.cv3.1.bn.num_batches_tracked perfectly matched!!
# model.21.cv4.conv.weight
# model.21.cv4.conv.weight perfectly matched!!
# model.21.cv4.bn.weight
# model.21.cv4.bn.weight perfectly matched!!
# model.21.cv4.bn.bias
# model.21.cv4.bn.bias perfectly matched!!
# model.21.cv4.bn.running_mean
# model.21.cv4.bn.running_mean perfectly matched!!
# model.21.cv4.bn.running_var
# model.21.cv4.bn.running_var perfectly matched!!
# model.21.cv4.bn.num_batches_tracked
# model.21.cv4.bn.num_batches_tracked perfectly matched!!
# model.22.cv2.0.0.conv.weight
# model.22.cv2.0.0.conv.weight perfectly matched!!
# model.22.cv2.0.0.bn.weight
# model.22.cv2.0.0.bn.weight perfectly matched!!
# model.22.cv2.0.0.bn.bias
# model.22.cv2.0.0.bn.bias perfectly matched!!
# model.22.cv2.0.0.bn.running_mean
# model.22.cv2.0.0.bn.running_mean perfectly matched!!
# model.22.cv2.0.0.bn.running_var
# model.22.cv2.0.0.bn.running_var perfectly matched!!
# model.22.cv2.0.0.bn.num_batches_tracked
# model.22.cv2.0.0.bn.num_batches_tracked perfectly matched!!
# model.22.cv2.0.1.conv.weight
# model.22.cv2.0.1.conv.weight perfectly matched!!
# model.22.cv2.0.1.bn.weight
# model.22.cv2.0.1.bn.weight perfectly matched!!
# model.22.cv2.0.1.bn.bias
# model.22.cv2.0.1.bn.bias perfectly matched!!
# model.22.cv2.0.1.bn.running_mean
# model.22.cv2.0.1.bn.running_mean perfectly matched!!
# model.22.cv2.0.1.bn.running_var
# model.22.cv2.0.1.bn.running_var perfectly matched!!
# model.22.cv2.0.1.bn.num_batches_tracked
# model.22.cv2.0.1.bn.num_batches_tracked perfectly matched!!
# model.22.cv2.0.2.weight
# model.22.cv2.0.2.weight perfectly matched!!
# model.22.cv2.0.2.bias
# model.22.cv2.0.2.bias perfectly matched!!
# model.22.cv2.1.0.conv.weight
# model.22.cv2.1.0.conv.weight perfectly matched!!
# model.22.cv2.1.0.bn.weight
# model.22.cv2.1.0.bn.weight perfectly matched!!
# model.22.cv2.1.0.bn.bias
# model.22.cv2.1.0.bn.bias perfectly matched!!
# model.22.cv2.1.0.bn.running_mean
# model.22.cv2.1.0.bn.running_mean perfectly matched!!
# model.22.cv2.1.0.bn.running_var
# model.22.cv2.1.0.bn.running_var perfectly matched!!
# model.22.cv2.1.0.bn.num_batches_tracked
# model.22.cv2.1.0.bn.num_batches_tracked perfectly matched!!
# model.22.cv2.1.1.conv.weight
# model.22.cv2.1.1.conv.weight perfectly matched!!
# model.22.cv2.1.1.bn.weight
# model.22.cv2.1.1.bn.weight perfectly matched!!
# model.22.cv2.1.1.bn.bias
# model.22.cv2.1.1.bn.bias perfectly matched!!
# model.22.cv2.1.1.bn.running_mean
# model.22.cv2.1.1.bn.running_mean perfectly matched!!
# model.22.cv2.1.1.bn.running_var
# model.22.cv2.1.1.bn.running_var perfectly matched!!
# model.22.cv2.1.1.bn.num_batches_tracked
# model.22.cv2.1.1.bn.num_batches_tracked perfectly matched!!
# model.22.cv2.1.2.weight
# model.22.cv2.1.2.weight perfectly matched!!
# model.22.cv2.1.2.bias
# model.22.cv2.1.2.bias perfectly matched!!
# model.22.cv2.2.0.conv.weight
# model.22.cv2.2.0.conv.weight perfectly matched!!
# model.22.cv2.2.0.bn.weight
# model.22.cv2.2.0.bn.weight perfectly matched!!
# model.22.cv2.2.0.bn.bias
# model.22.cv2.2.0.bn.bias perfectly matched!!
# model.22.cv2.2.0.bn.running_mean
# model.22.cv2.2.0.bn.running_mean perfectly matched!!
# model.22.cv2.2.0.bn.running_var
# model.22.cv2.2.0.bn.running_var perfectly matched!!
# model.22.cv2.2.0.bn.num_batches_tracked
# model.22.cv2.2.0.bn.num_batches_tracked perfectly matched!!
# model.22.cv2.2.1.conv.weight
# model.22.cv2.2.1.conv.weight perfectly matched!!
# model.22.cv2.2.1.bn.weight
# model.22.cv2.2.1.bn.weight perfectly matched!!
# model.22.cv2.2.1.bn.bias
# model.22.cv2.2.1.bn.bias perfectly matched!!
# model.22.cv2.2.1.bn.running_mean
# model.22.cv2.2.1.bn.running_mean perfectly matched!!
# model.22.cv2.2.1.bn.running_var
# model.22.cv2.2.1.bn.running_var perfectly matched!!
# model.22.cv2.2.1.bn.num_batches_tracked
# model.22.cv2.2.1.bn.num_batches_tracked perfectly matched!!
# model.22.cv2.2.2.weight
# model.22.cv2.2.2.weight perfectly matched!!
# model.22.cv2.2.2.bias
# model.22.cv2.2.2.bias perfectly matched!!
# model.22.cv3.0.0.conv.weight
# model.22.cv3.0.0.conv.weight perfectly matched!!
# model.22.cv3.0.0.bn.weight
# model.22.cv3.0.0.bn.weight perfectly matched!!
# model.22.cv3.0.0.bn.bias
# model.22.cv3.0.0.bn.bias perfectly matched!!
# model.22.cv3.0.0.bn.running_mean
# model.22.cv3.0.0.bn.running_mean perfectly matched!!
# model.22.cv3.0.0.bn.running_var
# model.22.cv3.0.0.bn.running_var perfectly matched!!
# model.22.cv3.0.0.bn.num_batches_tracked
# model.22.cv3.0.0.bn.num_batches_tracked perfectly matched!!
# model.22.cv3.0.1.conv.weight
# model.22.cv3.0.1.conv.weight perfectly matched!!
# model.22.cv3.0.1.bn.weight
# model.22.cv3.0.1.bn.weight perfectly matched!!
# model.22.cv3.0.1.bn.bias
# model.22.cv3.0.1.bn.bias perfectly matched!!
# model.22.cv3.0.1.bn.running_mean
# model.22.cv3.0.1.bn.running_mean perfectly matched!!
# model.22.cv3.0.1.bn.running_var
# model.22.cv3.0.1.bn.running_var perfectly matched!!
# model.22.cv3.0.1.bn.num_batches_tracked
# model.22.cv3.0.1.bn.num_batches_tracked perfectly matched!!
# model.22.cv3.0.2.weight
# model.22.cv3.0.2.weight perfectly matched!!
# model.22.cv3.0.2.bias
# model.22.cv3.0.2.bias perfectly matched!!
# model.22.cv3.1.0.conv.weight
# model.22.cv3.1.0.conv.weight perfectly matched!!
# model.22.cv3.1.0.bn.weight
# model.22.cv3.1.0.bn.weight perfectly matched!!
# model.22.cv3.1.0.bn.bias
# model.22.cv3.1.0.bn.bias perfectly matched!!
# model.22.cv3.1.0.bn.running_mean
# model.22.cv3.1.0.bn.running_mean perfectly matched!!
# model.22.cv3.1.0.bn.running_var
# model.22.cv3.1.0.bn.running_var perfectly matched!!
# model.22.cv3.1.0.bn.num_batches_tracked
# model.22.cv3.1.0.bn.num_batches_tracked perfectly matched!!
# model.22.cv3.1.1.conv.weight
# model.22.cv3.1.1.conv.weight perfectly matched!!
# model.22.cv3.1.1.bn.weight
# model.22.cv3.1.1.bn.weight perfectly matched!!
# model.22.cv3.1.1.bn.bias
# model.22.cv3.1.1.bn.bias perfectly matched!!
# model.22.cv3.1.1.bn.running_mean
# model.22.cv3.1.1.bn.running_mean perfectly matched!!
# model.22.cv3.1.1.bn.running_var
# model.22.cv3.1.1.bn.running_var perfectly matched!!
# model.22.cv3.1.1.bn.num_batches_tracked
# model.22.cv3.1.1.bn.num_batches_tracked perfectly matched!!
# model.22.cv3.1.2.weight
# model.22.cv3.1.2.weight perfectly matched!!
# model.22.cv3.1.2.bias
# model.22.cv3.1.2.bias perfectly matched!!
# model.22.cv3.2.0.conv.weight
# model.22.cv3.2.0.conv.weight perfectly matched!!
# model.22.cv3.2.0.bn.weight
# model.22.cv3.2.0.bn.weight perfectly matched!!
# model.22.cv3.2.0.bn.bias
# model.22.cv3.2.0.bn.bias perfectly matched!!
# model.22.cv3.2.0.bn.running_mean
# model.22.cv3.2.0.bn.running_mean perfectly matched!!
# model.22.cv3.2.0.bn.running_var
# model.22.cv3.2.0.bn.running_var perfectly matched!!
# model.22.cv3.2.0.bn.num_batches_tracked
# model.22.cv3.2.0.bn.num_batches_tracked perfectly matched!!
# model.22.cv3.2.1.conv.weight
# model.22.cv3.2.1.conv.weight perfectly matched!!
# model.22.cv3.2.1.bn.weight
# model.22.cv3.2.1.bn.weight perfectly matched!!
# model.22.cv3.2.1.bn.bias
# model.22.cv3.2.1.bn.bias perfectly matched!!
# model.22.cv3.2.1.bn.running_mean
# model.22.cv3.2.1.bn.running_mean perfectly matched!!
# model.22.cv3.2.1.bn.running_var
# model.22.cv3.2.1.bn.running_var perfectly matched!!
# model.22.cv3.2.1.bn.num_batches_tracked
# model.22.cv3.2.1.bn.num_batches_tracked perfectly matched!!
# model.22.cv3.2.2.weight
# model.22.cv3.2.2.weight perfectly matched!!
# model.22.cv3.2.2.bias
# model.22.cv3.2.2.bias perfectly matched!!
# model.22.dfl.conv.weight
# model.22.dfl.conv.weight perfectly matched!!

# %%
m_ckpt = {'model': model.half(),
          'optimizer': None,
          'best_fitness': None,
          'ema': None,
          'updates': None,
          'opt': None,
          'git': None,
          'date': None,
          'epoch': -1}
torch.save(m_ckpt, "/home/Huangzhe/test/runs/train_smoke/yolov9-s-smoke-s640_/weights/yolov9-s-converted.pt")

# %% [markdown]
# ## Convert YOLOv9-M

# %%
device = torch.device("cpu")
cfg = "./models/detect/gelan-m.yaml"
model = Model(cfg, ch=3, nc=80, anchors=3)
#model = model.half()
model = model.to(device)
_ = model.eval()
ckpt = torch.load('./yolov9-m.pt', map_location='cpu')
model.names = ckpt['model'].names
model.nc = ckpt['model'].nc

# %%
idx = 0
for k, v in model.state_dict().items():
    if "model.{}.".format(idx) in k:
        if idx < 22:
            kr = k.replace("model.{}.".format(idx), "model.{}.".format(idx+1))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv2.".format(idx) in k:
            kr = k.replace("model.{}.cv2.".format(idx), "model.{}.cv4.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv3.".format(idx) in k:
            kr = k.replace("model.{}.cv3.".format(idx), "model.{}.cv5.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.dfl.".format(idx) in k:
            kr = k.replace("model.{}.dfl.".format(idx), "model.{}.dfl2.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
    else:
        while True:
            idx += 1
            if "model.{}.".format(idx) in k:
                break
        if idx < 22:
            kr = k.replace("model.{}.".format(idx), "model.{}.".format(idx+1))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv2.".format(idx) in k:
            kr = k.replace("model.{}.cv2.".format(idx), "model.{}.cv4.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv3.".format(idx) in k:
            kr = k.replace("model.{}.cv3.".format(idx), "model.{}.cv5.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.dfl.".format(idx) in k:
            kr = k.replace("model.{}.dfl.".format(idx), "model.{}.dfl2.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
_ = model.eval()

# %%
m_ckpt = {'model': model.half(),
          'optimizer': None,
          'best_fitness': None,
          'ema': None,
          'updates': None,
          'opt': None,
          'git': None,
          'date': None,
          'epoch': -1}
torch.save(m_ckpt, "./yolov9-m-converted.pt")

# %% [markdown]
# ## Convert YOLOv9-C

# %%
device = torch.device("cpu")
cfg = "./models/detect/gelan-c.yaml"
model = Model(cfg, ch=3, nc=80, anchors=3)
#model = model.half()
model = model.to(device)
_ = model.eval()
ckpt = torch.load('./yolov9-c.pt', map_location='cpu')
model.names = ckpt['model'].names
model.nc = ckpt['model'].nc

# %%
idx = 0
for k, v in model.state_dict().items():
    if "model.{}.".format(idx) in k:
        if idx < 22:
            kr = k.replace("model.{}.".format(idx), "model.{}.".format(idx+1))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
        elif "model.{}.cv2.".format(idx) in k:
            kr = k.replace("model.{}.cv2.".format(idx), "model.{}.cv4.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
        elif "model.{}.cv3.".format(idx) in k:
            kr = k.replace("model.{}.cv3.".format(idx), "model.{}.cv5.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
        elif "model.{}.dfl.".format(idx) in k:
            kr = k.replace("model.{}.dfl.".format(idx), "model.{}.dfl2.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
    else:
        while True:
            idx += 1
            if "model.{}.".format(idx) in k:
                break
        if idx < 22:
            kr = k.replace("model.{}.".format(idx), "model.{}.".format(idx+1))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
        elif "model.{}.cv2.".format(idx) in k:
            kr = k.replace("model.{}.cv2.".format(idx), "model.{}.cv4.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
        elif "model.{}.cv3.".format(idx) in k:
            kr = k.replace("model.{}.cv3.".format(idx), "model.{}.cv5.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
        elif "model.{}.dfl.".format(idx) in k:
            kr = k.replace("model.{}.dfl.".format(idx), "model.{}.dfl2.".format(idx+16))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
_ = model.eval()

# %%
m_ckpt = {'model': model.half(),
          'optimizer': None,
          'best_fitness': None,
          'ema': None,
          'updates': None,
          'opt': None,
          'git': None,
          'date': None,
          'epoch': -1}
torch.save(m_ckpt, "./yolov9-c-converted.pt")

# %% [markdown]
# ## Convert YOLOv9-E

# %%
device = torch.device("cpu")
cfg = "./models/detect/gelan-e.yaml"
model = Model(cfg, ch=3, nc=80, anchors=3)
#model = model.half()
model = model.to(device)
_ = model.eval()
ckpt = torch.load('./yolov9-e.pt', map_location='cpu')
model.names = ckpt['model'].names
model.nc = ckpt['model'].nc

# %%
idx = 0
for k, v in model.state_dict().items():
    if "model.{}.".format(idx) in k:
        if idx < 29:
            kr = k.replace("model.{}.".format(idx), "model.{}.".format(idx))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif idx < 42:
            kr = k.replace("model.{}.".format(idx), "model.{}.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv2.".format(idx) in k:
            kr = k.replace("model.{}.cv2.".format(idx), "model.{}.cv4.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv3.".format(idx) in k:
            kr = k.replace("model.{}.cv3.".format(idx), "model.{}.cv5.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.dfl.".format(idx) in k:
            kr = k.replace("model.{}.dfl.".format(idx), "model.{}.dfl2.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
    else:
        while True:
            idx += 1
            if "model.{}.".format(idx) in k:
                break
        if idx < 29:
            kr = k.replace("model.{}.".format(idx), "model.{}.".format(idx))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif idx < 42:
            kr = k.replace("model.{}.".format(idx), "model.{}.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv2.".format(idx) in k:
            kr = k.replace("model.{}.cv2.".format(idx), "model.{}.cv4.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.cv3.".format(idx) in k:
            kr = k.replace("model.{}.cv3.".format(idx), "model.{}.cv5.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
        elif "model.{}.dfl.".format(idx) in k:
            kr = k.replace("model.{}.dfl.".format(idx), "model.{}.dfl2.".format(idx+7))
            model.state_dict()[k] -= model.state_dict()[k]
            model.state_dict()[k] += ckpt['model'].state_dict()[kr]
            print(k, "perfectly matched!!")
_ = model.eval()

# %%
m_ckpt = {'model': model.half(),
          'optimizer': None,
          'best_fitness': None,
          'ema': None,
          'updates': None,
          'opt': None,
          'git': None,
          'date': None,
          'epoch': -1}
torch.save(m_ckpt, "./yolov9-e-converted.pt")
